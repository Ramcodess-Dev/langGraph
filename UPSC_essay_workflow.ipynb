# %%
from langgraph.graph import StateGraph
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv
from pydantic import BaseModel, Field

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model="gpt-4o-mini")

# %%
class EvaluationSchema(BaseModel):

    feedback: str = Field(description="Detailed Feedback on the essay")
    score:int = Field(description='Score out of 10', ge=10, le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %%
Artificial Intelligence (AI) has emerged as one of the most transformative technologies of the 21st century. It refers to the ability of machines and computer systems to perform tasks that normally require human intelligence, such as learning, reasoning, problem-solving, understanding language, and recognizing images. In India, AI is becoming increasingly important and is influencing various sectors, including education, healthcare, agriculture, finance, transportation, and business.

One of the most significant areas where AI can contribute to India is **healthcare**. AI-powered systems can help doctors analyze medical images, identify diseases at an early stage, and assist in clinical decision-making. AI can also support remote healthcare services, which is particularly useful for people living in rural and underserved areas. By combining AI with India's growing digital infrastructure, healthcare services can potentially become more accessible and efficient.

AI also has an important role in **agriculture**, which supports a large portion of India's population. AI-based technologies can analyze weather conditions, soil quality, satellite images, and crop data to help farmers make better decisions. AI can assist in detecting crop diseases, predicting yields, and improving irrigation and fertilizer usage. These applications can help increase productivity while reducing unnecessary resource consumption.

In **education**, AI can provide personalized learning experiences. Intelligent learning platforms can identify a student's strengths and weaknesses and recommend suitable study materials. AI-powered tutors and language-learning tools can also provide students with assistance at any time. For a country as large and diverse as India, AI could help expand access to educational resources and support learning in multiple Indian languages.

The **business and technology sectors** are also being transformed by AI. Indian companies are using AI for customer service, data analysis, fraud detection, software development, marketing, and automation. AI is creating new opportunities for startups and entrepreneurs while also changing the skills required in the job market. As AI adoption increases, knowledge of data, programming, critical thinking, and AI-related technologies is likely to become increasingly valuable.

AI can also contribute to **governance and public services**. Governments can use AI to analyze large amounts of data, improve service delivery, detect fraudulent activities, and make public systems more efficient. India's large digital ecosystem provides significant opportunities for applying AI to public infrastructure and citizen services.

However, the growth of AI also presents several challenges. **Job displacement, privacy, cybersecurity, algorithmic bias, misinformation, and unequal access to technology** are important concerns. AI systems can sometimes produce incorrect or biased results, and excessive dependence on automated systems may create additional risks. Therefore, India needs responsible AI development supported by appropriate regulations, transparency, data protection, and human oversight.

India has the potential to become an important global center for AI because of its large technology workforce, growing startup ecosystem, expanding digital infrastructure, and diverse population. At the same time, the benefits of AI should reach people across different regions and socioeconomic backgrounds rather than being limited to a small section of society.

In conclusion, Artificial Intelligence has the potential to play a major role in India's economic and social development. From healthcare and agriculture to education, business, and governance, AI can improve efficiency and create new opportunities. However, its development must be responsible, inclusive, and human-centered. If India successfully balances technological innovation with ethics, education, privacy, and social responsibility, AI can become an important tool for building a more productive and digitally empowered nation.
# Out:
#   Cell In[25], line 1
#     Artificial Intelligence (AI) has emerged as one of the most transformative technologies of the 21st century. It refers to the ability of machines and computer systems to perform tasks that normally require human intelligence, such as learning, reasoning, problem-solving, understanding language, and recognizing images. In India, AI is becoming increasingly important and is influencing various sectors, including education, healthcare, agriculture, finance, transportation, and business.
#                                                                                                     ^
# SyntaxError: invalid decimal literal

# %%
class UPSCState(TypedDict):

    essay : str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback : str
    overall_feedback : str
    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %%
def evaluate_language(state: UPSCState)

# %%
graph = StateGraph(UPSCState)

graph.add_node('evaluate_language', evaluate_language)
graph.add_node('evaluate_analysis', evaluate_analysis)
graph.add_node('evaluate_thought', evaluate_thought)
graph.add_node('final_evaluation', final_evaluation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 graph = StateGraph(UPSCState)
#       2
#       3 graph.add_node('evaluate_language', evaluate_language)
#       4 graph.add_node('evaluate_analysis', evaluate_analysis)
#
# File ~\OneDrive\Desktop\langGraph\myenv\Lib\site-packages\langgraph\graph\state.py:268, in StateGraph.__init__(self, state_schema, context_schema, input_schema, output_schema, **kwargs)
#     264 self.context_schema = context_schema
#     266 self._node_defaults: _NodeDefaults = _NodeDefaults()
# --> 268 self._add_schema(self.state_schema)
#     269 self._add_schema(self.input_schema, allow_managed=False)
#     270 self._add_schema(self.output_schema, allow_managed=False)
#
# File ~\OneDrive\Desktop\langGraph\myenv\Lib\site-packages\langgraph\graph\state.py:346, in StateGraph._add_schema(self, schema, allow_managed)
# ...
